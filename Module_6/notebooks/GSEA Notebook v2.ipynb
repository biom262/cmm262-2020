# %% [markdown]
# <table style="border:2px solid white;" cellspacing="0" cellpadding="0" border-collapse: collapse; border-spacing: 0;>
#   <tr>
#     <th style="background-color:white"> <img src="../media/cnt_logo_700.png" width=250 height=250></th>
#     <th style="background-color:white"> <img src="../media/CCAL.png" width=210 height=210></th>
#     <th style="background-color:white"> <img src="../media/logoMoores.jpg" width=170 height=170></th>
#     <th style="background-color:white"> <img src="../media/UCSD_School_of_Medicine_logo.png" width=175 height=175></th>
#   </tr>
# </table>

# %% [markdown]
# # GSEA Notebook v2
#
# # Find the Mystery Pathway

# %% [markdown]
# <hr style="border: none; border-bottom: 3px solid #88BBEE;">

# %% [markdown]
# ## Configure notebook

# %% [markdown]
# %load_ext autoreload
# %autoreload 2
#
# import numpy
# import matplotlib.pyplot as plt
# from plotly.offline import init_notebook_mode
# init_notebook_mode(connected = True)
# import plotly as py
# import pandas as pd
# import numpy as np
# np.random.seed(7678)
#
# import sys
# sys.path.insert(0, '../tools/')
# import ccal
#
# import random
# import warnings
# warnings.filterwarnings('ignore')
#
# py.offline.init_notebook_mode(connected=True)
#
# from IPython.display import display, HTML
#
# display(HTML(data="""
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>
# """))

# %% [markdown]
# ### Read the Hallmarks collection from MSigDB

# %%
gmt1 = '../data/h.all.v7.0.symbols.gmt'
gene_sets = ccal.read_gmts([gmt1], collapse=False)
gene_sets
# Out:
#                                              Gene 0    Gene 1  Gene 10  \
# Gene Set
# HALLMARK_TNFA_SIGNALING_VIA_NFKB               KLF4      BCL3    RCAN1
# HALLMARK_HYPOXIA                               HEXA   FAM162A  PPP1R3C
# HALLMARK_CHOLESTEROL_HOMEOSTASIS                LPL       MVK    ANXA5
# HALLMARK_MITOTIC_SPINDLE                     PPP4R2      PLK1    TUBD1
# HALLMARK_WNT_BETA_CATENIN_SIGNALING            DKK1      TP53    HDAC5
# HALLMARK_TGF_BETA_SIGNALING                    CDK9  SERPINE1     BMP2
# HALLMARK_IL6_JAK_STAT3_SIGNALING              IL3RA     PTPN1    CRLF2
# HALLMARK_DNA_REPAIR                          NELFCD    TARBP2      PNP
# HALLMARK_G2M_CHECKPOINT                       RAD21      PLK1    KIF15
# HALLMARK_APOPTOSIS                          SLC20A1     IGF2R    ERBB3
# HALLMARK_NOTCH_SIGNALING                      SAP30      DLL1     DTX4
# HALLMARK_ADIPOGENESIS                           LPL      DLAT     SNCG
# HALLMARK_ESTROGEN_RESPONSE_EARLY               KLF4   SLC24A3    RBBP8
# HALLMARK_ESTROGEN_RESPONSE_LATE             SLC24A3      KLF4    TSTA3
# HALLMARK_ANDROGEN_RESPONSE                    MERTK   GUCY1A1    GNAI3
# HALLMARK_MYOGENESIS                           ITGB1   ATP6AP1      GAA
# HALLMARK_PROTEIN_SECRETION                    VAMP7     IGF2R    RAB2A
# HALLMARK_INTERFERON_ALPHA_RESPONSE           TRIM25      LY6E    IFI30
# HALLMARK_INTERFERON_GAMMA_RESPONSE            IFIT1    TRIM25      PNP
# HALLMARK_APICAL_JUNCTION                      ITGB1     SIRPA      NF2
# HALLMARK_APICAL_SURFACE                        THY1  SLC22A12    SULF2
# HALLMARK_HEDGEHOG_SIGNALING                    THY1     PTCH1     CDK6
# HALLMARK_COMPLEMENT                           USP15     ERAP2    CEBPB
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE            IFIT1       FUS    YIF1A
# HALLMARK_PI3K_AKT_MTOR_SIGNALING              THEM4     ARPC3    MKNK2
# HALLMARK_MTORC1_SIGNALING                       UNG      PLK1     YKT6
# HALLMARK_E2F_TARGETS                            UNG     RAD21   ANP32E
# HALLMARK_MYC_TARGETS_V1                       PCBP1     PSMD3    SRPK1
# HALLMARK_MYC_TARGETS_V2                        RCL1       UNG     PLK4
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION     DKK1     ITGB1    FBLN2
# HALLMARK_INFLAMMATORY_RESPONSE               SLAMF1      ROS1     EREG
# HALLMARK_XENOBIOTIC_METABOLISM                HACL1      MAOA  HSD17B2
# HALLMARK_FATTY_ACID_METABOLISM                PDHA1      MAOA     GLUL
# HALLMARK_OXIDATIVE_PHOSPHORYLATION            PDHA1   ATP5F1E     SDHC
# HALLMARK_GLYCOLYSIS                          NDUFV3   FAM162A    MED24
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY       GPX4     PRDX4      GSR
# HALLMARK_P53_PATHWAY                        FAM162A      KLF4    PDGFA
# HALLMARK_UV_RESPONSE_UP                       POLG2      HTR7    ABCB1
# HALLMARK_UV_RESPONSE_DN                     SIPA1L1     MAGI2   COL3A1
# HALLMARK_ANGIOGENESIS                           LPL   PGLYRP1   S100A4
# HALLMARK_HEME_METABOLISM                      ACKR1     USP15   RNF19A
# HALLMARK_COAGULATION                            F12     TFPI2    MEP1A
# HALLMARK_IL2_STAT5_SIGNALING                  IL3RA   TNFRSF8     TLR7
# HALLMARK_BILE_ACID_METABOLISM                 HACL1      FDXR    ABCA3
# HALLMARK_PEROXISOME                           CADM1     ISOC1     ECI2
# HALLMARK_ALLOGRAFT_REJECTION                 MAP3K7      BCL3      B2M
# HALLMARK_SPERMATOGENESIS                      CCT6B     TSSK2      NF2
# HALLMARK_KRAS_SIGNALING_UP                  GUCY1A1    ZNF639     ETV5
# HALLMARK_KRAS_SIGNALING_DN                    PRODH     NPY4R    SIDT1
# HALLMARK_PANCREAS_BETA_CELLS                   LMO2     HNF1A    G6PC2
#
#                                            Gene 100   Gene 101  Gene 102  \
# Gene Set
# HALLMARK_TNFA_SIGNALING_VIA_NFKB               KLF2     SLC2A3   GADD45B
# HALLMARK_HYPOXIA                             KLHL24      HSPA5     ERO1A
# HALLMARK_CHOLESTEROL_HOMEOSTASIS               None       None      None
# HALLMARK_MITOTIC_SPINDLE                      KIF3B       ANLN      NEK2
# HALLMARK_WNT_BETA_CATENIN_SIGNALING            None       None      None
# HALLMARK_TGF_BETA_SIGNALING                    None       None      None
# HALLMARK_IL6_JAK_STAT3_SIGNALING               None       None      None
# HALLMARK_DNA_REPAIR                         ARL6IP1     NUDT21      RFC4
# HALLMARK_G2M_CHECKPOINT                        NEK2      NUP98      UPF1
# HALLMARK_APOPTOSIS                              GSN        FAS      IL18
# HALLMARK_NOTCH_SIGNALING                       None       None      None
# HALLMARK_ADIPOGENESIS                         CIDEA         CS    SLC5A6
# HALLMARK_ESTROGEN_RESPONSE_EARLY             DEPTOR      LRIG1     OVOL2
# HALLMARK_ESTROGEN_RESPONSE_LATE              HSPA4L      OVOL2     TIAM1
# HALLMARK_ANDROGEN_RESPONSE                     None       None      None
# HALLMARK_MYOGENESIS                         GADD45B      LPIN1       HRC
# HALLMARK_PROTEIN_SECRETION                     None       None      None
# HALLMARK_INTERFERON_ALPHA_RESPONSE             None       None      None
# HALLMARK_INTERFERON_GAMMA_RESPONSE            STAT1      CASP1    PSMB10
# HALLMARK_APICAL_JUNCTION                      CADM2      ARPC2     ADAM9
# HALLMARK_APICAL_SURFACE                        None       None      None
# HALLMARK_HEDGEHOG_SIGNALING                    None       None      None
# HALLMARK_COMPLEMENT                           ADAM9      PDGFB        C9
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE            SPCS3     IGFBP1    KDELR3
# HALLMARK_PI3K_AKT_MTOR_SIGNALING            ARHGDIA       HRAS       IL4
# HALLMARK_MTORC1_SIGNALING                      STC1     SLC1A5       CFP
# HALLMARK_E2F_TARGETS                          CCNE1      POLD1    MAD2L1
# HALLMARK_MYC_TARGETS_V1                       EIF4E      POLE3     SRSF7
# HALLMARK_MYC_TARGETS_V2                        None       None      None
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION     IL15      TIMP3    IGFBP3
# HALLMARK_INFLAMMATORY_RESPONSE                P2RY2     GPR132       NDP
# HALLMARK_XENOBIOTIC_METABOLISM                  PTS       PMM1       DDT
# HALLMARK_FATTY_ACID_METABOLISM                 UROS       CBR3  HSD17B11
# HALLMARK_OXIDATIVE_PHOSPHORYLATION           NDUFV1       MTX2   ATP5F1B
# HALLMARK_GLYCOLYSIS                            FBP2       ALG1     RRAGD
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY       None       None      None
# HALLMARK_P53_PATHWAY                           PMM1    SLC7A11    ACVR1B
# HALLMARK_UV_RESPONSE_UP                         FOS      PSMC3      NXF1
# HALLMARK_UV_RESPONSE_DN                        ICA1       DLG1      TJP1
# HALLMARK_ANGIOGENESIS                          None       None      None
# HALLMARK_HEME_METABOLISM                       EZH1      NR3C1      BCAM
# HALLMARK_COAGULATION                           PROC        FN1     CRIP2
# HALLMARK_IL2_STAT5_SIGNALING                  CCNE1  EEF1AKMT1     ITGAE
# HALLMARK_BILE_ACID_METABOLISM                  PEX7      SOAT2      AQP9
# HALLMARK_PEROXISOME                             CAT       FIS1     ACSL1
# HALLMARK_ALLOGRAFT_REJECTION                   CCL7      CD247     GCNT1
# HALLMARK_SPERMATOGENESIS                      PACRG      SYCP1     PDHA2
# HALLMARK_KRAS_SIGNALING_UP                   CLEC4A      WDR33    SNAP25
# HALLMARK_KRAS_SIGNALING_DN                   ENTPD7       CPB1      AMBN
# HALLMARK_PANCREAS_BETA_CELLS                   None       None      None
#
#                                             Gene 103 Gene 104  Gene 105  \
# Gene Set
# HALLMARK_TNFA_SIGNALING_VIA_NFKB               NFKB2    PTPRE      MAFF
# HALLMARK_HYPOXIA                                GPC3    NR3C1     DUSP1
# HALLMARK_CHOLESTEROL_HOMEOSTASIS                None     None      None
# HALLMARK_MITOTIC_SPINDLE                        SMC4  ARHGEF7     TIAM1
# HALLMARK_WNT_BETA_CATENIN_SIGNALING             None     None      None
# HALLMARK_TGF_BETA_SIGNALING                     None     None      None
# HALLMARK_IL6_JAK_STAT3_SIGNALING                None     None      None
# HALLMARK_DNA_REPAIR                            POLA2   GTF2H3      UMPS
# HALLMARK_G2M_CHECKPOINT                         ABL1     RBL1      MCM3
# HALLMARK_APOPTOSIS                             SATB1    PDCD4       HGF
# HALLMARK_NOTCH_SIGNALING                        None     None      None
# HALLMARK_ADIPOGENESIS                        GADD45A    ABCA1      RTN3
# HALLMARK_ESTROGEN_RESPONSE_EARLY               GFRA1    RAB17      AQP3
# HALLMARK_ESTROGEN_RESPONSE_LATE                 PRLR   TPSAB1      BATF
# HALLMARK_ANDROGEN_RESPONSE                      None     None      None
# HALLMARK_MYOGENESIS                            ACTC1   IGFBP3     MYH11
# HALLMARK_PROTEIN_SECRETION                      None     None      None
# HALLMARK_INTERFERON_ALPHA_RESPONSE              None     None      None
# HALLMARK_INTERFERON_GAMMA_RESPONSE              IL15     OAS2      NOD1
# HALLMARK_APICAL_JUNCTION                        NEXN    TUBG1      STX4
# HALLMARK_APICAL_SURFACE                         None     None      None
# HALLMARK_HEDGEHOG_SIGNALING                     None     None      None
# HALLMARK_COMPLEMENT                             LRP1     PLAT     ZFPM2
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE            EIF4A2    NOLC1   EIF2AK3
# HALLMARK_PI3K_AKT_MTOR_SIGNALING             PIKFYVE    MAPK9      None
# HALLMARK_MTORC1_SIGNALING                     DHCR24    UCHL5    TMEM97
# HALLMARK_E2F_TARGETS                           PTTG1   HNRNPD     CKS1B
# HALLMARK_MYC_TARGETS_V1                        NCBP1   MAD2L1    HNRNPD
# HALLMARK_MYC_TARGETS_V2                         None     None      None
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION       ID2     SCG2     SFRP4
# HALLMARK_INFLAMMATORY_RESPONSE                 P2RX7    PTGIR      GPC3
# HALLMARK_XENOBIOTIC_METABOLISM                 ATOH8    ENPEP   SLC46A3
# HALLMARK_FATTY_ACID_METABOLISM                NCAPH2   BMPR1B     EPHX1
# HALLMARK_OXIDATIVE_PHOSPHORYLATION            POLR2F   NDUFA5     ISCA1
# HALLMARK_GLYCOLYSIS                            P4HA2     CLN6     RBCK1
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY        None     None      None
# HALLMARK_P53_PATHWAY                          HSPA4L  GADD45A     CASP1
# HALLMARK_UV_RESPONSE_UP                         BTG3   DNAJA1      RFC4
# HALLMARK_UV_RESPONSE_DN                         CAP2    NFKB1  CDC42BPA
# HALLMARK_ANGIOGENESIS                           None     None      None
# HALLMARK_HEME_METABOLISM                       BACH1    GATA1      LMO2
# HALLMARK_COAGULATION                           RABIF     CTSV       CFB
# HALLMARK_IL2_STAT5_SIGNALING                  PHLDA1     GPX4  TNFRSF21
# HALLMARK_BILE_ACID_METABOLISM                ALDH1A1  SLC35B2     NR0B2
# HALLMARK_PEROXISOME                         SERPINA6     None      None
# HALLMARK_ALLOGRAFT_REJECTION                   STAT1    HLA-E     ZAP70
# HALLMARK_SPERMATOGENESIS                       CCNA1     GSG1     CCNB2
# HALLMARK_KRAS_SIGNALING_UP                      PLAT    CIDEA     GPNMB
# HALLMARK_KRAS_SIGNALING_DN                      LFNG     KRT1     KCNQ2
# HALLMARK_PANCREAS_BETA_CELLS                    None     None      None
#
#                                            Gene 106   ...     Gene 90  \
# Gene Set                                              ...
# HALLMARK_TNFA_SIGNALING_VIA_NFKB               HES1   ...      CXCL11
# HALLMARK_HYPOXIA                              PDGFB   ...        KLF6
# HALLMARK_CHOLESTEROL_HOMEOSTASIS               None   ...        None
# HALLMARK_MITOTIC_SPINDLE                      TAOK2   ...       RASA1
# HALLMARK_WNT_BETA_CATENIN_SIGNALING            None   ...        None
# HALLMARK_TGF_BETA_SIGNALING                    None   ...        None
# HALLMARK_IL6_JAK_STAT3_SIGNALING               None   ...        None
# HALLMARK_DNA_REPAIR                            AAAS   ...       ZWINT
# HALLMARK_G2M_CHECKPOINT                       H2AFZ   ...       PTTG1
# HALLMARK_APOPTOSIS                             RELA   ...        IL1A
# HALLMARK_NOTCH_SIGNALING                       None   ...        None
# HALLMARK_ADIPOGENESIS                          MDH2   ...      RETSAT
# HALLMARK_ESTROGEN_RESPONSE_EARLY              TIAM1   ...     TBC1D30
# HALLMARK_ESTROGEN_RESPONSE_LATE               IMPA2   ...     SLC29A1
# HALLMARK_ANDROGEN_RESPONSE                     None   ...       ABHD2
# HALLMARK_MYOGENESIS                           HDAC5   ...       WWTR1
# HALLMARK_PROTEIN_SECRETION                     None   ...       TPD52
# HALLMARK_INTERFERON_ALPHA_RESPONSE             None   ...        IRF2
# HALLMARK_INTERFERON_GAMMA_RESPONSE           CXCL10   ...       PTPN2
# HALLMARK_APICAL_JUNCTION                      ACTN1   ...       CADM3
# HALLMARK_APICAL_SURFACE                        None   ...        None
# HALLMARK_HEDGEHOG_SIGNALING                    None   ...        None
# HALLMARK_COMPLEMENT                           PRKCD   ...       CALM3
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE          HSP90B1   ...        NHP2
# HALLMARK_PI3K_AKT_MTOR_SIGNALING               None   ...       TRAF2
# HALLMARK_MTORC1_SIGNALING                   CYP51A1   ...       FADS1
# HALLMARK_E2F_TARGETS                          TUBG1   ...       SRSF1
# HALLMARK_MYC_TARGETS_V1                       PSMC6   ...       NOP16
# HALLMARK_MYC_TARGETS_V2                        None   ...        None
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION   TGFBR3   ...      COL8A2
# HALLMARK_INFLAMMATORY_RESPONSE                 RTP4   ...         LCK
# HALLMARK_XENOBIOTIC_METABOLISM               PSMB10   ...      IGFBP4
# HALLMARK_FATTY_ACID_METABOLISM                 VNN1   ...       PCBD1
# HALLMARK_OXIDATIVE_PHOSPHORYLATION             MAOB   ...      NDUFB4
# HALLMARK_GLYCOLYSIS                            MDH2   ...        PYGL
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY       None   ...        None
# HALLMARK_P53_PATHWAY                          PTPRE   ...       TRAF4
# HALLMARK_UV_RESPONSE_UP                       SHOX2   ...      TUBA4A
# HALLMARK_UV_RESPONSE_DN                       ANXA4   ...      NOTCH2
# HALLMARK_ANGIOGENESIS                          None   ...        None
# HALLMARK_HEME_METABOLISM                      ACSL6   ...      MBOAT2
# HALLMARK_COAGULATION                             F8   ...       PROS1
# HALLMARK_IL2_STAT5_SIGNALING                  GATA1   ...      SLC1A5
# HALLMARK_BILE_ACID_METABOLISM                  PFKM   ...        LIPE
# HALLMARK_PEROXISOME                            None   ...       CTPS1
# HALLMARK_ALLOGRAFT_REJECTION                  TRAT1   ...        IRF7
# HALLMARK_SPERMATOGENESIS                       TLE4   ...       CAMK4
# HALLMARK_KRAS_SIGNALING_UP                   ITGBL1   ...        MAP7
# HALLMARK_KRAS_SIGNALING_DN                    KCNN1   ...       CDH16
# HALLMARK_PANCREAS_BETA_CELLS                   None   ...        None
#
#                                              Gene 91   Gene 92  Gene 93  \
# Gene Set
# HALLMARK_TNFA_SIGNALING_VIA_NFKB                 GEM     PLPP3  B4GALT5
# HALLMARK_HYPOXIA                             B3GALT6    PPFIA4     GYS1
# HALLMARK_CHOLESTEROL_HOMEOSTASIS                None      None     None
# HALLMARK_MITOTIC_SPINDLE                      INCENP  RAB3GAP1    DOCK4
# HALLMARK_WNT_BETA_CATENIN_SIGNALING             None      None     None
# HALLMARK_TGF_BETA_SIGNALING                     None      None     None
# HALLMARK_IL6_JAK_STAT3_SIGNALING                None      None     None
# HALLMARK_DNA_REPAIR                            ERCC3      NME3     DDB2
# HALLMARK_G2M_CHECKPOINT                       HNRNPD     STAG1    CKS1B
# HALLMARK_APOPTOSIS                             BIRC3      PRF1     XIAP
# HALLMARK_NOTCH_SIGNALING                        None      None     None
# HALLMARK_ADIPOGENESIS                           ECH1      MGLL   NDUFA5
# HALLMARK_ESTROGEN_RESPONSE_EARLY               CLDN7    BCL11B  SLC16A1
# HALLMARK_ESTROGEN_RESPONSE_LATE                PTPN6     CLIC3  SLC16A1
# HALLMARK_ANDROGEN_RESPONSE                     PIAS1     TPD52    CCND3
# HALLMARK_MYOGENESIS                              AK1    SYNGR2     TCAP
# HALLMARK_PROTEIN_SECRETION                    RAB22A      STAM     NAPA
# HALLMARK_INTERFERON_ALPHA_RESPONSE               C1S      IRF9    PSMA3
# HALLMARK_INTERFERON_GAMMA_RESPONSE            CSF2RB    ARID5B     RTP4
# HALLMARK_APICAL_JUNCTION                        RRAS    ITGA10    RASA1
# HALLMARK_APICAL_SURFACE                         None      None     None
# HALLMARK_HEDGEHOG_SIGNALING                     None      None     None
# HALLMARK_COMPLEMENT                          XPNPEP1      IRF7    PRSS3
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE             SDAD1      CCL2    CHAC1
# HALLMARK_PI3K_AKT_MTOR_SIGNALING                CLTC     GSK3B    PITX2
# HALLMARK_MTORC1_SIGNALING                   SERPINH1     LTA4H    PSMA4
# HALLMARK_E2F_TARGETS                             LBR      PCNA   DEPDC1
# HALLMARK_MYC_TARGETS_V1                        VDAC1      LSM7    NCBP2
# HALLMARK_MYC_TARGETS_V2                         None      None     None
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION       FAP      GPC1    PLOD2
# HALLMARK_INFLAMMATORY_RESPONSE                 ADRM1     MARCO  IL18RAP
# HALLMARK_XENOBIOTIC_METABOLISM               SLC6A12    RETSAT     ECH1
# HALLMARK_FATTY_ACID_METABOLISM                 CIDEA      HPGD     MDH2
# HALLMARK_OXIDATIVE_PHOSPHORYLATION          SLC25A12   ATP6V0C    HTRA2
# HALLMARK_GLYCOLYSIS                            ERO1A     CHST1    CLDN3
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY        None      None     None
# HALLMARK_P53_PATHWAY                           RPL36      KLK8   CGRRF1
# HALLMARK_UV_RESPONSE_UP                         RXRB     MARK2   DNAJB1
# HALLMARK_UV_RESPONSE_DN                         FHL2      RXRA     TFPI
# HALLMARK_ANGIOGENESIS                           None      None     None
# HALLMARK_HEME_METABOLISM                         BSG    DCAF11  ALDH6A1
# HALLMARK_COAGULATION                            F13B      CTSE     PLAU
# HALLMARK_IL2_STAT5_SIGNALING                   AKAP2      TGM2     DRC1
# HALLMARK_BILE_ACID_METABOLISM                  ABCA8     PXMP2     PAOX
# HALLMARK_PEROXISOME                             SOD2     ACAA1    ABCC8
# HALLMARK_ALLOGRAFT_REJECTION                   BCL10     APBB1     IL13
# HALLMARK_SPERMATOGENESIS                       HOXB1      CST8    HTR5A
# HALLMARK_KRAS_SIGNALING_UP                   TSPAN13     PLAUR   MTMR10
# HALLMARK_KRAS_SIGNALING_DN                     COQ8A    PCDHB1  SLC29A3
# HALLMARK_PANCREAS_BETA_CELLS                    None      None     None
#
#                                             Gene 94   Gene 95   Gene 96  \
# Gene Set
# HALLMARK_TNFA_SIGNALING_VIA_NFKB              DUSP1    PHLDA1    PDLIM5
# HALLMARK_HYPOXIA                              HOXB9      TGM2     PLAUR
# HALLMARK_CHOLESTEROL_HOMEOSTASIS               None      None      None
# HALLMARK_MITOTIC_SPINDLE                    RAPGEF6       TTK    CEP192
# HALLMARK_WNT_BETA_CATENIN_SIGNALING            None      None      None
# HALLMARK_TGF_BETA_SIGNALING                    None      None      None
# HALLMARK_IL6_JAK_STAT3_SIGNALING               None      None      None
# HALLMARK_DNA_REPAIR                          POLR3C     PRIM1     POLD3
# HALLMARK_G2M_CHECKPOINT                        HUS1     HMGA1    MAPK14
# HALLMARK_APOPTOSIS                            NEDD9     IFNB1      BTG3
# HALLMARK_NOTCH_SIGNALING                       None      None      None
# HALLMARK_ADIPOGENESIS                          MRAP     NABP1    SUCLG1
# HALLMARK_ESTROGEN_RESPONSE_EARLY            RETREG1      XBP1     CLIC3
# HALLMARK_ESTROGEN_RESPONSE_LATE                XBP1  SERPINA1   FAM102A
# HALLMARK_ANDROGEN_RESPONSE                  TNFAIP8     ZMIZ1      SGK1
# HALLMARK_MYOGENESIS                             AGL     TNNT3     AEBP1
# HALLMARK_PROTEIN_SECRETION                   ARFIP1     STX16      None
# HALLMARK_INTERFERON_ALPHA_RESPONSE             OGFR     PARP9    IFITM1
# HALLMARK_INTERFERON_GAMMA_RESPONSE             LAP3   RAPGEF6    PARP14
# HALLMARK_APICAL_JUNCTION                      CLDN7      NRTN    CX3CL1
# HALLMARK_APICAL_SURFACE                        None      None      None
# HALLMARK_HEDGEHOG_SIGNALING                    None      None      None
# HALLMARK_COMPLEMENT                           GNGT2     HSPA5     CALM1
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE             IMP3     SPCS1     SRPRA
# HALLMARK_PI3K_AKT_MTOR_SIGNALING              ACTR2   HSP90B1     GNGT1
# HALLMARK_MTORC1_SIGNALING                      USO1      NFYC     BCAT1
# HALLMARK_E2F_TARGETS                          PSIP1  RAD51AP1    CDC25A
# HALLMARK_MYC_TARGETS_V1                        RPS2    CLNS1A     PSMD8
# HALLMARK_MYC_TARGETS_V2                        None      None      None
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION   FERMT2      LRP1   GADD45A
# HALLMARK_INFLAMMATORY_RESPONSE                 LCP2      IRF7       SRI
# HALLMARK_XENOBIOTIC_METABOLISM                 GAD1     FETUB     NDRG2
# HALLMARK_FATTY_ACID_METABOLISM                HSDL2   CYP4A22     H2AFZ
# HALLMARK_OXIDATIVE_PHOSPHORYLATION           NDUFS3     VDAC1    BCKDHA
# HALLMARK_GLYCOLYSIS                            GPC3      HAX1      GPC1
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY       None      None      None
# HALLMARK_P53_PATHWAY                          RAD9A       AK1     COQ8A
# HALLMARK_UV_RESPONSE_UP                       EPCAM     EPHX1       RET
# HALLMARK_UV_RESPONSE_DN                        LDLR    CITED2     PMP22
# HALLMARK_ANGIOGENESIS                          None      None      None
# HALLMARK_HEME_METABOLISM                      EPB41     SIDT2     HTRA2
# HALLMARK_COAGULATION                           CTSB    LEFTY2  SERPINE1
# HALLMARK_IL2_STAT5_SIGNALING                   CISH      IL13      XBP1
# HALLMARK_BILE_ACID_METABOLISM                 GNPAT     PRDX5     NR3C2
# HALLMARK_PEROXISOME                            PEX2     PEX14   SLC35B2
# HALLMARK_ALLOGRAFT_REJECTION                  PTPN6     MRPL3   HLA-DMB
# HALLMARK_SPERMATOGENESIS                    SLC12A2      MTOR    TOPBP1
# HALLMARK_KRAS_SIGNALING_UP                     SLPI       BTC     ERO1A
# HALLMARK_KRAS_SIGNALING_DN                   ABCB11     GPR19      CLPS
# HALLMARK_PANCREAS_BETA_CELLS                   None      None      None
#
#                                              Gene 97     Gene 98  Gene 99
# Gene Set
# HALLMARK_TNFA_SIGNALING_VIA_NFKB               IFIT2     GADD45A    ABCA1
# HALLMARK_HYPOXIA                                HAS1     XPNPEP1   BNIP3L
# HALLMARK_CHOLESTEROL_HOMEOSTASIS                None        None     None
# HALLMARK_MITOTIC_SPINDLE                      PDLIM5     RAPGEF5    CEP72
# HALLMARK_WNT_BETA_CATENIN_SIGNALING             None        None     None
# HALLMARK_TGF_BETA_SIGNALING                     None        None     None
# HALLMARK_IL6_JAK_STAT3_SIGNALING                None        None     None
# HALLMARK_DNA_REPAIR                             POLB      VPS37D   NT5C3A
# HALLMARK_G2M_CHECKPOINT                       YTHDC1       NUP50     SMC4
# HALLMARK_APOPTOSIS                           TNFSF10      DNAJA1     MCL1
# HALLMARK_NOTCH_SIGNALING                        None        None     None
# HALLMARK_ADIPOGENESIS                          EPHX2        GPX4    ESRRA
# HALLMARK_ESTROGEN_RESPONSE_EARLY               P2RY2        MREG  FAM102A
# HALLMARK_ESTROGEN_RESPONSE_LATE                FABP5      METTL3   RABEP1
# HALLMARK_ANDROGEN_RESPONSE                     NGLY1       CCND1  TMEM50A
# HALLMARK_MYOGENESIS                             PKIA       DAPK2   SORBS3
# HALLMARK_PROTEIN_SECRETION                      None        None     None
# HALLMARK_INTERFERON_ALPHA_RESPONSE              None        None     None
# HALLMARK_INTERFERON_GAMMA_RESPONSE             IFIT2        CCL7    RBCK1
# HALLMARK_APICAL_JUNCTION                       NFASC      CLDN15    PLCG1
# HALLMARK_APICAL_SURFACE                         None        None     None
# HALLMARK_HEDGEHOG_SIGNALING                     None        None     None
# HALLMARK_COMPLEMENT                         SERPINA1       DOCK4     LAP3
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE            EIF2S1        IARS    NOP14
# HALLMARK_PI3K_AKT_MTOR_SIGNALING               ECSIT       RPTOR   AKT1S1
# HALLMARK_MTORC1_SIGNALING                       ETF1        ACLY   TM7SF2
# HALLMARK_E2F_TARGETS                            E2F8         TK1     XPO1
# HALLMARK_MYC_TARGETS_V1                     HSP90AB1       HSPE1     XPO1
# HALLMARK_MYC_TARGETS_V2                         None        None     None
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION   GADD45B        PFN2      DCN
# HALLMARK_INFLAMMATORY_RESPONSE                   VIP      CXCL11   CX3CL1
# HALLMARK_XENOBIOTIC_METABOLISM                CYP1A2        CES1   PDLIM5
# HALLMARK_FATTY_ACID_METABOLISM                   MIF       APEX1    ETFDH
# HALLMARK_OXIDATIVE_PHOSPHORYLATION              MFN2      RETSAT     ECH1
# HALLMARK_GLYCOLYSIS                            PLOD2        GPC4      AGL
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY        None        None     None
# HALLMARK_P53_PATHWAY                          CDKN2B      HEXIM1   ZNF365
# HALLMARK_UV_RESPONSE_UP                        MMP14        RPN1   CDKN1C
# HALLMARK_UV_RESPONSE_DN                      PRKAR2B       ATXN1     MT1E
# HALLMARK_ANGIOGENESIS                           None        None     None
# HALLMARK_HEME_METABOLISM                      BNIP3L  AC092338.1    ISCA1
# HALLMARK_COAGULATION                           APOC2        BMP1    MSRB2
# HALLMARK_IL2_STAT5_SIGNALING                   CAPN3       SPRY4  FAM126B
# HALLMARK_BILE_ACID_METABOLISM                   BMP6     SLC23A1     PHYH
# HALLMARK_PEROXISOME                          ALDH1A1        MSH2     HRAS
# HALLMARK_ALLOGRAFT_REJECTION                   FASLG        CD47     CD3G
# HALLMARK_SPERMATOGENESIS                         IDE       ZNRF4    DPEP3
# HALLMARK_KRAS_SIGNALING_UP                    NAP1L2        ANO1      MMD
# HALLMARK_KRAS_SIGNALING_DN                     ACTC1        ASB7    TNNI3
# HALLMARK_PANCREAS_BETA_CELLS                    None        None     None
#
# [50 rows x 200 columns]

# %% [markdown]
# ### Read Expression File for 750 Cancer Cell Lines
# ##### Cancer Cell Line Encyclopedia: dataset from the [Dependencies Map Project at the Broad Institute](https://depmap.org/portal/). This is a great resource for cancer research in general.

# %%
ccle_exp = ccal.read_gct('../data/ccle_gene_expression.gct')
print(ccle_exp.shape)
# Out:
# (48642, 750)

# %% [markdown]
# ### Read Drug Sensitivity Database
# ##### [Cancer Therapeutics Response Portal](https://portals.broadinstitute.org/ctrp.v2.1/). This is part of the [Cancer Target Discovery and Development Network (CTD2)](https://ocg.cancer.gov/programs/ctd2) project sponsored by the NCI Offcie of Cancer Genomics. UCSD is also a member of this network.

# %%
ccle_drug_sens = ccal.read_gct('../data/ccle_drug_sensitivity.gct')
print(ccle_drug_sens.shape)
# Out:
# (481, 645)

# %% [markdown]
# ### To select a single drug as phenotype extract the relevant row using the drug name
# #### The use of the notnull function is to remove NA values (some drugs do not have entries for all cell lines)

# %%
phen = ccle_drug_sens.loc['drug name', pd.notnull(ccle_drug_sens.loc['drug name',:])]
phen

# %% [markdown]
# # Find the Mystery Pathway
#
# ## The exercise consists of the following. Using the 3 datasets already loaded in the notebook:
#
# ### I. The Hallmarks gene sets (gene_sets)
# ### II. The CCLE gene expression dataset (ccle_exp)
# ### III. The CTRP drug sensitivity dataset (ccle_drug_sens)
#
# ### 1.- Define a phenotype based on the drug sensitivty for the compound ML162 in the CTRP dataset (row name 'ML162'). This drug is a representative of a new type of therapeutic compounds that induce "ferroptosis" cellular death. See for example the [ferroptosis](https://en.wikipedia.org/wiki/Ferroptosis) page in wikipedia. Notice that in the CTRP dataset lower values imply higher sensitivity to the drug (Area under the curve drug sensitivity metric).
#
# ### 2.- Use single_sample GSEA function from the first notebook) to produce a dataset of pathways (hallmarks) vs. samples. You can do this by cutting and pasting the ccal.ssGSEA function from the first notebook and setting the parameters accordingly. This could take about 5-10 minutes.
#
# ### 3.- Use the make_match_panel function to match the ssGSEA profiles of the hallmark gene sets againt the drug response of ML162. You can do this by cutting and pasting the ccal.make_match_panel function from the first notebook and setting the parameters accordingly.
#
# ### Based on your results answers these two questions:
#
# ### A. What is the pathway most associated with response to the ML162 compound? In other words, What is the cellular context or molecular pathway associated with response? This could be answered based on the best scoring hallmark from 2.
#
# ### B. What are the cancer types more sensitive to ML162? To do this just sort the ML162 phenotype and see which cell lines (and cancer types) correspond to the smallest values of the ML162 sensitivity profile. You can do this using the pandas sorting function: dataset.sort_values(ascending=True).
#
# ### Both questions are important as there are pharmaceutical companies developing clinical-grade drugs similar to ML162 to be used to treat human patients. In this context it is important to know how cancer patients could be selected as candidates for this drug based on some key molecular biomarkers (pathway) and/or cancer tissue type.

# %% [markdown]
# ### Now try to see if you can answer those two questions
#
#
# ### If you get stuck, you can peek at the solution which is shown at the end of this notebook. However, only do that after a good try.

# %% [markdown]
# ## This is the Solution

# %% [markdown]
# ## Extract the profile of the ML162 compound

# %%
phen = ccle_drug_sens.loc['ML162', pd.notnull(ccle_drug_sens.loc['ML162',:])]
phen
# Out:
# CHP212_AUTONOMIC_GANGLIA             10.3520
# IMR32_AUTONOMIC_GANGLIA               4.8662
# KELLY_AUTONOMIC_GANGLIA               9.8269
# KPNSI9S_AUTONOMIC_GANGLIA             9.5538
# KPNYN_AUTONOMIC_GANGLIA               9.2834
# MHHNB11_AUTONOMIC_GANGLIA            11.6980
# NB1_AUTONOMIC_GANGLIA                 9.9825
# NH6_AUTONOMIC_GANGLIA                 7.8775
# SIMA_AUTONOMIC_GANGLIA               10.0620
# SKNAS_AUTONOMIC_GANGLIA               7.7706
# SKNBE2_AUTONOMIC_GANGLIA              7.6312
# SKNDZ_AUTONOMIC_GANGLIA               2.5079
# SKNSH_AUTONOMIC_GANGLIA              10.7390
# HUH28_BILIARY_TRACT                   7.6524
# SNU1079_BILIARY_TRACT                 6.7048
# SNU1196_BILIARY_TRACT                 7.9141
# SNU308_BILIARY_TRACT                 10.6410
# SNU478_BILIARY_TRACT                 10.6680
# SNU869_BILIARY_TRACT                  9.6990
# A673_BONE                             6.4476
# CAL78_BONE                           11.7890
# G292CLONEA141B1_BONE                  7.0571
# HOS_BONE                              9.7988
# SUIT2_PANCREAS                       11.1510
# HS822T_BONE                           6.7950
# HS888T_BONE                           6.5743
# MG63_BONE                             6.5355
# MHHES1_BONE                           6.6514
# SAOS2_BONE                           10.1040
# SJSA1_BONE                           10.4710
#                                       ...
# SCC4_UPPER_AERODIGESTIVE_TRACT        9.9310
# SCC9_UPPER_AERODIGESTIVE_TRACT        9.2264
# SNU1041_UPPER_AERODIGESTIVE_TRACT    12.7520
# SNU1066_UPPER_AERODIGESTIVE_TRACT     8.7879
# SNU1076_UPPER_AERODIGESTIVE_TRACT     8.5381
# SNU1214_UPPER_AERODIGESTIVE_TRACT     8.5354
# SNU46_UPPER_AERODIGESTIVE_TRACT      10.8260
# SNU899_UPPER_AERODIGESTIVE_TRACT     14.3180
# YD10B_UPPER_AERODIGESTIVE_TRACT      12.6860
# YD38_UPPER_AERODIGESTIVE_TRACT       10.8830
# YD8_UPPER_AERODIGESTIVE_TRACT         7.6256
# 5637_URINARY_TRACT                    8.1013
# 639V_URINARY_TRACT                   14.6020
# 647V_URINARY_TRACT                    8.5287
# BC3C_URINARY_TRACT                   14.4740
# HT1197_URINARY_TRACT                 10.3620
# HT1376_URINARY_TRACT                 12.9620
# JMSU1_URINARY_TRACT                   8.1590
# KMBC2_URINARY_TRACT                  10.1440
# KU1919_URINARY_TRACT                 10.3310
# RT112_URINARY_TRACT                  10.5160
# RT4_URINARY_TRACT                    10.5230
# SCABER_URINARY_TRACT                  6.9740
# AM38_CENTRAL_NERVOUS_SYSTEM           4.2962
# T24_URINARY_TRACT                     9.0002
# TCCSUP_URINARY_TRACT                 10.4910
# UBLC1_URINARY_TRACT                   8.6246
# UMUC1_URINARY_TRACT                  10.5470
# UMUC3_URINARY_TRACT                  14.0770
# VMCUB1_URINARY_TRACT                 14.3640
# Name: ML162, Length: 620, dtype: float64

# %% [markdown]
# ### Run the ssGSEA analysis to produce a dataset of pathways vs. samples

# %%
pathway_exp = ccal.ssGSEA(
    ccle_exp, 
    gene_sets, 
    statistic="auc", 
    alpha = 1,
    file_path=None,
    sample_norm_type='zscore'
)
# Out:
# Estimating ssGSEA for sample #1 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #2 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #3 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #4 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #5 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #6 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #7 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #8 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #9 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #10 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #11 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #12 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #13 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #14 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #15 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #16 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #17 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #18 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #19 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #20 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #21 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #22 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #23 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #24 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #25 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #26 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #27 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #28 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #29 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #30 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #31 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #32 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #33 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #34 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #35 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #36 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #37 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #38 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #39 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #40 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #41 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #42 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #43 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #44 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #45 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #46 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #47 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #48 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #49 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #50 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #51 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #52 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #53 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #54 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #55 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #56 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #57 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #58 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #59 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #60 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #61 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #62 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #63 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #64 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #65 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #66 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #67 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #68 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #69 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #70 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #71 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #72 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #73 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #74 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #75 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #76 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #77 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #78 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #79 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #80 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #81 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #82 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #83 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #84 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #85 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #86 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #87 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #88 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #89 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #90 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #91 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #92 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #93 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #94 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #95 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #96 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #97 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #98 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #99 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #100 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #101 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #102 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #103 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #104 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #105 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #106 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #107 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #108 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #109 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #110 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #111 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #112 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #113 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #114 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #115 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #116 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #117 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #118 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #119 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #120 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #121 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #122 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #123 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #124 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #125 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #126 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #127 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #128 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #129 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #130 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #131 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #132 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #133 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #134 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #135 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #136 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #137 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #138 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #139 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #140 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #141 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #142 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #143 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #144 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #145 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #146 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #147 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #148 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #149 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #150 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #151 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #152 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #153 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #154 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #155 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #156 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #157 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #158 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #159 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #160 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #161 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #162 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #163 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #164 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #165 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #166 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #167 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #168 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #169 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #170 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #171 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #172 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #173 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #174 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #175 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #176 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #177 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #178 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #179 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #180 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #181 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #182 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #183 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #184 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #185 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #186 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #187 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #188 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #189 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #190 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #191 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #192 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #193 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #194 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #195 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #196 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #197 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #198 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #199 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #200 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #201 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #202 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #203 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #204 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #205 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #206 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #207 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #208 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #209 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #210 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #211 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #212 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #213 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #214 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #215 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #216 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #217 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #218 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #219 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #220 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #221 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #222 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #223 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #224 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #225 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #226 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #227 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #228 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #229 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #230 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #231 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #232 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #233 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #234 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #235 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #236 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #237 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #238 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #239 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #240 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #241 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #242 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #243 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #244 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #245 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #246 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #247 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #248 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #249 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #250 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #251 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #252 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #253 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #254 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #255 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #256 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #257 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #258 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #259 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #260 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #261 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #262 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #263 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #264 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #265 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #266 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #267 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #268 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #269 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #270 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #271 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #272 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #273 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #274 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #275 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #276 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #277 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #278 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #279 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #280 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #281 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #282 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #283 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #284 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #285 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #286 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #287 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #288 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #289 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #290 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #291 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #292 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #293 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #294 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #295 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #296 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #297 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #298 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #299 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #300 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #301 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #302 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #303 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #304 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #305 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #306 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #307 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #308 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #309 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #310 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #311 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #312 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #313 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #314 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #315 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #316 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #317 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #318 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #319 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #320 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #321 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #322 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #323 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #324 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #325 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #326 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #327 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #328 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #329 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #330 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #331 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #332 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #333 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #334 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #335 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #336 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #337 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #338 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #339 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #340 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #341 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #342 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #343 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #344 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #345 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #346 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #347 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #348 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #349 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #350 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #351 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #352 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #353 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #354 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #355 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #356 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #357 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #358 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #359 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #360 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #361 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #362 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #363 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #364 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #365 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #366 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #367 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #368 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #369 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #370 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #371 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #372 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #373 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #374 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #375 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #376 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #377 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #378 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #379 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #380 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #381 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #382 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #383 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #384 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #385 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #386 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #387 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #388 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #389 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #390 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #391 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #392 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #393 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #394 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #395 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #396 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #397 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #398 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #399 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #400 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #401 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #402 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #403 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #404 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #405 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #406 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #407 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #408 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #409 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #410 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #411 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #412 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #413 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #414 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #415 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #416 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #417 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #418 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #419 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #420 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #421 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #422 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #423 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #424 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #425 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #426 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #427 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #428 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #429 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #430 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #431 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #432 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #433 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #434 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #435 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #436 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #437 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #438 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #439 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #440 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #441 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #442 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #443 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #444 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #445 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #446 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #447 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #448 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #449 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #450 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #451 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #452 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #453 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #454 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #455 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #456 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #457 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #458 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #459 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #460 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #461 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #462 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #463 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #464 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #465 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #466 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #467 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #468 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #469 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #470 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #471 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #472 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #473 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #474 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #475 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #476 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #477 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #478 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #479 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #480 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #481 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #482 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #483 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #484 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #485 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #486 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #487 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #488 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #489 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #490 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #491 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #492 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #493 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #494 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #495 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #496 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #497 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #498 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #499 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #500 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #501 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #502 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #503 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #504 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #505 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #506 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #507 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #508 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #509 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #510 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #511 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #512 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #513 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #514 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #515 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #516 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #517 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #518 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #519 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #520 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #521 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #522 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #523 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #524 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #525 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #526 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #527 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #528 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #529 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #530 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #531 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #532 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #533 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #534 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #535 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #536 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #537 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #538 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #539 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #540 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #541 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #542 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #543 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #544 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #545 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #546 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #547 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #548 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #549 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #550 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #551 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #552 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #553 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #554 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #555 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #556 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #557 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #558 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #559 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #560 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #561 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #562 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #563 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #564 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #565 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #566 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #567 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #568 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #569 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #570 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #571 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #572 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #573 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #574 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #575 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #576 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #577 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #578 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #579 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #580 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #581 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #582 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #583 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #584 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #585 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #586 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #587 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #588 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #589 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #590 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #591 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #592 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #593 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #594 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #595 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #596 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #597 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #598 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #599 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #600 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #601 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #602 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #603 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #604 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #605 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #606 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #607 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #608 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #609 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #610 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #611 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #612 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #613 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #614 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #615 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #616 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #617 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #618 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #619 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #620 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #621 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #622 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #623 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #624 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #625 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #626 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #627 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #628 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #629 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #630 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #631 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #632 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #633 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #634 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #635 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #636 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #637 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #638 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #639 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #640 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #641 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #642 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #643 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #644 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #645 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #646 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #647 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #648 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #649 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #650 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #651 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #652 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #653 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #654 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #655 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #656 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #657 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #658 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #659 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #660 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #661 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #662 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #663 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #664 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #665 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #666 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #667 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #668 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #669 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #670 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #671 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #672 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #673 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #674 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #675 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #676 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #677 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #678 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #679 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #680 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #681 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #682 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #683 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #684 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #685 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #686 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #687 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #688 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #689 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #690 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #691 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #692 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #693 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #694 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #695 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #696 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #697 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #698 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #699 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #700 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #701 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #702 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #703 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #704 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #705 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #706 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #707 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #708 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #709 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #710 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #711 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #712 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #713 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #714 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #715 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #716 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #717 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #718 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #719 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #720 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #721 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #722 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #723 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #724 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #725 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #726 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #727 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #728 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #729 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #730 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #731 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #732 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #733 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #734 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #735 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #736 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #737 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #738 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #739 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #740 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #741 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #742 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #743 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #744 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #745 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #746 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #747 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #748 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #749 (out of 750) for 50 gene sets
# Estimating ssGSEA for sample #750 (out of 750) for 50 gene sets

# %% [markdown]
# ### Now match the dataset of pathways vs samples against the profile of the ML162 compound

# %%
DPE_scores = ccal.make_match_panel(
                target = phen,
                target_type = 'continuous',
                target_ascending = True,
                data = pathway_exp,
                data_type = 'continuous',
                n_extreme = 50,
                n_permutation = 10,
                n_sampling = 50,
                plot_std = 2,
                score_ascending = True,
                title = ' ',
                layout_width = 1100, 
                row_height = 50, 
                layout_side_margin = 260, 
                annotation_font_size = 9,
                file_path_prefix = '../results/ML162_sens_vs_pathways.html')
# Out:
# target.index (620) & data.columns (750) have 577 in common.
# Computing score using compute_information_coefficient with 1 process ...
# Computing MoE with 50 sampling ...
# Computing p-value and FDR with 10 permutation ...
# ../results/erastin_sens_vs_pathways.html.html
# <div>
#
#
#             <div id="05493fdc-a7fd-423e-b44a-703fba63274e" class="plotly-graph-div" style="height:1179.7029875297292px; width:1100px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("05493fdc-a7fd-423e-b44a-703fba63274e")) {
#                     Plotly.newPlot(
#                         '05493fdc-a7fd-423e-b44a-703fba63274e',
#                         [{"colorscale": [[0.0, "#0000ff"], [0.00392156862745098, "#0202ff"], [0.00784313725490196, "#0404ff"], [0.011764705882352941, "#0606ff"], [0.01568627450980392, "#0808ff"], [0.0196078431372549, "#0a0aff"], [0.023529411764705882, "#0c0cff"], [0.027450980392156862, "#0e0eff"], [0.03137254901960784, "#1010ff"], [0.03529411764705882, "#1212ff"], [0.0392156862745098, "#1414ff"], [0.043137254901960784, "#1616ff"], [0.047058823529411764, "#1818ff"], [0.050980392156862744, "#1a1aff"], [0.054901960784313725, "#1c1cff"], [0.058823529411764705, "#1e1eff"], [0.06274509803921569, "#2020ff"], [0.06666666666666667, "#2222ff"], [0.07058823529411765, "#2424ff"], [0.07450980392156863, "#2626ff"], [0.0784313725490196, "#2828ff"], [0.08235294117647059, "#2a2aff"], [0.08627450980392157, "#2c2cff"], [0.09019607843137255, "#2e2eff"], [0.09411764705882353, "#3030ff"], [0.09803921568627451, "#3232ff"], [0.10196078431372549, "#3434ff"], [0.10588235294117647, "#3636ff"], [0.10980392156862745, "#3838ff"], [0.11372549019607843, "#3a3aff"], [0.11764705882352941, "#3c3cff"], [0.12156862745098039, "#3e3eff"], [0.12549019607843137, "#4040ff"], [0.12941176470588237, "#4242ff"], [0.13333333333333333, "#4444ff"], [0.13725490196078433, "#4646ff"], [0.1411764705882353, "#4848ff"], [0.1450980392156863, "#4a4aff"], [0.14901960784313725, "#4c4cff"], [0.15294117647058825, "#4e4eff"], [0.1568627450980392, "#5050ff"], [0.1607843137254902, "#5252ff"], [0.16470588235294117, "#5454ff"], [0.16862745098039217, "#5656ff"], [0.17254901960784313, "#5858ff"], [0.17647058823529413, "#5a5aff"], [0.1803921568627451, "#5c5cff"], [0.1843137254901961, "#5e5eff"], [0.18823529411764706, "#6060ff"], [0.19215686274509805, "#6262ff"], [0.19607843137254902, "#6464ff"], [0.2, "#6666ff"], [0.20392156862745098, "#6868ff"], [0.20784313725490197, "#6a6aff"], [0.21176470588235294, "#6c6cff"], [0.21568627450980393, "#6e6eff"], [0.2196078431372549, "#7070ff"], [0.2235294117647059, "#7272ff"], [0.22745098039215686, "#7474ff"], [0.23137254901960785, "#7676ff"], [0.23529411764705882, "#7878ff"], [0.23921568627450981, "#7a7aff"], [0.24313725490196078, "#7c7cff"], [0.24705882352941178, "#7e7eff"], [0.25098039215686274, "#8080ff"], [0.2549019607843137, "#8282ff"], [0.25882352941176473, "#8484ff"], [0.2627450980392157, "#8686ff"], [0.26666666666666666, "#8888ff"], [0.27058823529411763, "#8a8aff"], [0.27450980392156865, "#8c8cff"], [0.2784313725490196, "#8e8eff"], [0.2823529411764706, "#9090ff"], [0.28627450980392155, "#9292ff"], [0.2901960784313726, "#9494ff"], [0.29411764705882354, "#9696ff"], [0.2980392156862745, "#9898ff"], [0.30196078431372547, "#9a9aff"], [0.3058823529411765, "#9c9cff"], [0.30980392156862746, "#9e9eff"], [0.3137254901960784, "#a0a0ff"], [0.3176470588235294, "#a2a2ff"], [0.3215686274509804, "#a4a4ff"], [0.3254901960784314, "#a6a6ff"], [0.32941176470588235, "#a8a8ff"], [0.3333333333333333, "#aaaaff"], [0.33725490196078434, "#acacff"], [0.3411764705882353, "#aeaeff"], [0.34509803921568627, "#b0b0ff"], [0.34901960784313724, "#b2b2ff"], [0.35294117647058826, "#b4b4ff"], [0.3568627450980392, "#b6b6ff"], [0.3607843137254902, "#b8b8ff"], [0.36470588235294116, "#babaff"], [0.3686274509803922, "#bcbcff"], [0.37254901960784315, "#bebeff"], [0.3764705882352941, "#c0c0ff"], [0.3803921568627451, "#c2c2ff"], [0.3843137254901961, "#c4c4ff"], [0.38823529411764707, "#c6c6ff"], [0.39215686274509803, "#c8c8ff"], [0.396078431372549, "#cacaff"], [0.4, "#ccccff"], [0.403921568627451, "#ceceff"], [0.40784313725490196, "#d0d0ff"], [0.4117647058823529, "#d2d2ff"], [0.41568627450980394, "#d4d4ff"], [0.4196078431372549, "#d6d6ff"], [0.4235294117647059, "#d8d8ff"], [0.42745098039215684, "#dadaff"], [0.43137254901960786, "#dcdcff"], [0.43529411764705883, "#dedeff"], [0.4392156862745098, "#e0e0ff"], [0.44313725490196076, "#e2e2ff"], [0.4470588235294118, "#e4e4ff"], [0.45098039215686275, "#e6e6ff"], [0.4549019607843137, "#e8e8ff"], [0.4588235294117647, "#eaeaff"], [0.4627450980392157, "#ececf ...

# %% [markdown]
# ### Now look at the cell lines (names) with lower ML162 levels

# %%
phen.sort_values(ascending = True)
# Out:
# SKNDZ_AUTONOMIC_GANGLIA                        2.5079
# OV7_OVARY                                      2.6479
# D283MED_CENTRAL_NERVOUS_SYSTEM                 2.7238
# LOXIMVI_SKIN                                   3.5063
# HS934T_SKIN                                    4.1445
# NCIH522_LUNG                                   4.2349
# AM38_CENTRAL_NERVOUS_SYSTEM                    4.2962
# IALM_LUNG                                      4.3319
# 8505C_THYROID                                  4.5002
# SNU182_LIVER                                   4.5783
# RKN_SOFT_TISSUE                                4.5793
# TE5_OESOPHAGUS                                 4.6046
# NCIH1341_LUNG                                  4.6450
# IMR32_AUTONOMIC_GANGLIA                        4.8662
# CAL54_KIDNEY                                   4.8784
# JVM2_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE        5.0302
# SNU8_OVARY                                     5.1242
# BT20_BREAST                                    5.2077
# SNU1033_LARGE_INTESTINE                        5.2188
# OSRC2_KIDNEY                                   5.2403
# SNU119_OVARY                                   5.3543
# ES2_OVARY                                      5.5378
# NCIH1693_LUNG                                  5.5860
# NCIH1184_LUNG                                  5.6525
# LS123_LARGE_INTESTINE                          5.7783
# TOV21G_OVARY                                   5.7824
# KASUMI2_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     6.1314
# NCIH23_LUNG                                    6.1404
# CMLT1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE       6.1754
# KP4_PANCREAS                                   6.2006
#                                                ...
# VMCUB1_URINARY_TRACT                          14.3640
# NCIH460_LUNG                                  14.3660
# GAMG_CENTRAL_NERVOUS_SYSTEM                   14.4160
# NCIH322_LUNG                                  14.4420
# BC3C_URINARY_TRACT                            14.4740
# NCIH1944_LUNG                                 14.4810
# KYSE180_OESOPHAGUS                            14.5290
# TE6_OESOPHAGUS                                14.5780
# KPL1_BREAST                                   14.5870
# SKMEL5_SKIN                                   14.5890
# NCIH2126_LUNG                                 14.5960
# 639V_URINARY_TRACT                            14.6020
# TE9_OESOPHAGUS                                14.6100
# TE4_OESOPHAGUS                                14.6440
# SKMEL30_SKIN                                  14.6970
# HARA_LUNG                                     14.6970
# SKMEL28_SKIN                                  14.7210
# NCIH2023_LUNG                                 14.7250
# CFPAC1_PANCREAS                               14.7300
# HCT8_LARGE_INTESTINE                          14.7880
# NCIH2122_LUNG                                 14.7980
# HUH1_LIVER                                    14.8050
# GSU_STOMACH                                   14.8080
# NCIH1792_LUNG                                 14.8630
# HELA                                          14.8960
# MORCPR_LUNG                                   14.8990
# MKN45_STOMACH                                 14.9320
# PATU8902_PANCREAS                             14.9880
# BEN_LUNG                                      15.2350
# TTTHYROID                                     16.1610
# Name: ML162, Length: 620, dtype: float64

# %% [markdown]
# ### Based on these results the answer is
#
# ## The Ephitelial Mesenchymal Transition (EMT)
#
# ### and the relevant cancers are, for example:
#
# ## autonomic ganglia, ovary, central nervous system, skin and lung

# %% [markdown]
# ### If you had performed this analysis in the context of a real cancer project 4 years ago you could have become the co-author of a high-profile cancer paper:
#
# [Viswanathan et al. 2017 Dependency of a therapy-resistant state of cancer cells on a lipid peroxidase pathway Nature. 2017 Jul 27; 547(7664): 453–457.](https://www.nature.com/articles/nature23007)
#
# ### and help open up a new potential area of development for novel cancer therapeutics
